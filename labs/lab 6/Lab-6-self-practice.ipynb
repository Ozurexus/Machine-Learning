# %% [markdown]
# ### Lab-6 : Self-Practice
#
# In this week self practice, you will apply [SVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html) on multi-class problem. In the following 3-class generated blobs you will train SVCs in a one-vs-one and one-vs-rest approach. Draw the decision bounderies of each approach.

# %% [markdown]
# #### Question: Recall what the difference between one-vs-one and on-vs-rest for multiclass classification is.

# %%
from sklearn.datasets import make_blobs 
import matplotlib.pyplot as plt

# %%
# we create the dataset
X, y = make_blobs(n_samples=1500, centers=3, n_features=2, cluster_std=0.60,
                  random_state=0)

plt.scatter(X[:, 0], X[:, 1],  marker=".", s=10)

# %% [markdown]
# ### Create a svc model to classify the data point using one-vs-one approach and draw the desicion bounderies (hyperplan and margins)

# %%
### Create a svc model to classify the data point using one-vs-one approach and draw the desicion bounderies (hyperplan and margins)

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# split the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# create the model
svc = SVC(kernel='linear', decision_function_shape='ovo')

# train the model
svc.fit(X_train, y_train)

# predict the test data
y_pred = svc.predict(X_test)

# calculate the accuracy
accuracy_score(y_test, y_pred)

# draw the decision bounderies
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X, y, clf=svc, legend=2)

# look at the support vectors
print(svc.support_vectors_)

# look at the number of support vectors for each class
print(svc.n_support_)

# look at the number of support vectors for each class
print(svc.n_support_)
# Out:
# [[-4.42234212e-01  4.31598784e+00]
#  [-3.96901945e-01  4.45467798e+00]
#  [ 1.62318846e+00  2.76827653e+00]
#  [ 5.82391874e-01  2.60305462e+00]
#  [-6.19233264e-01  4.66757904e+00]
#  [ 2.47459031e+00  2.95659434e+00]
#  [ 7.40836680e-01  2.47610149e+00]
#  [ 1.49382769e+00  2.71041587e+00]
#  [-1.94812382e-01  3.90785229e+00]
#  [ 1.54209773e+00  2.65998103e+00]
#  [ 1.21569789e+00  2.64023167e+00]
#  [-6.91436401e-02  3.52184167e+00]
#  [ 7.48321369e-02  3.23718715e+00]
#  [-2.33573898e-01  3.98011455e+00]
#  [-3.24608508e-02  3.77040451e+00]
#  [-3.31063719e-03  3.36312669e+00]
#  [ 1.20159058e+00  2.05105851e+00]
#  [ 2.06137883e+00  2.21664146e+00]
#  [ 1.23616980e+00  2.06592285e+00]
#  [ 5.92728906e-01  1.56661840e+00]
#  [ 1.45925070e+00  2.12290695e+00]
#  [ 2.37934134e+00  2.27194390e+00]
#  [ 1.10577083e+00  2.24382480e+00]
#  [ 2.07177334e+00  2.23687349e+00]
#  [ 3.88852034e-01  1.58870404e+00]
#  [ 1.50347711e+00  2.48342509e+00]
#  [-6.19920403e-01  3.94176321e+00]
#  [-4.13756288e-01  3.76727600e+00]
#  [-4.92686248e-01  3.34569200e+00]
#  [-3.78366195e-01  1.91830862e+00]
#  [ 2.30553732e-01  3.05159726e+00]
#  [-8.20206310e-01  1.53478215e+00]
#  [-3.55847406e-01  3.66184659e+00]
#  [-4.83108531e-02  3.03418130e+00]
#  [-3.81298438e-01  3.91620614e+00]
#  [-7.51316401e-01  3.82681164e+00]
#  [-5.00402064e-01  3.76653129e+00]
#  [-3.42444044e-01  3.20456740e+00]
#  [-3.46266204e-01  3.18649219e+00]]
# [16 10 13]
# [16 10 13]

# %% [markdown]
# ### Create a svc model to classify the data points using one-vs-rest approach and draw the desicion bounderies

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# split the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# create the model
svc1 = SVC(kernel='linear', decision_function_shape='ovr')

# train the model
svc1.fit(X_train, y_train)

# predict the test data
y_pred = svc1.predict(X_test)

# calculate the accuracy
accuracy_score(y_test, y_pred)

# draw the decision bounderies
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X, y, clf=svc1, legend=2)

# look at the support vectors
print(svc1.support_vectors_)

# look at the number of support vectors for each class
print(svc1.n_support_)

# look at the number of support vectors for each class
print(svc1.n_support_)
# Out:
# [[-4.42234212e-01  4.31598784e+00]
#  [-3.96901945e-01  4.45467798e+00]
#  [ 1.62318846e+00  2.76827653e+00]
#  [ 5.82391874e-01  2.60305462e+00]
#  [-6.19233264e-01  4.66757904e+00]
#  [ 2.47459031e+00  2.95659434e+00]
#  [ 7.40836680e-01  2.47610149e+00]
#  [ 1.49382769e+00  2.71041587e+00]
#  [-1.94812382e-01  3.90785229e+00]
#  [ 1.54209773e+00  2.65998103e+00]
#  [ 1.21569789e+00  2.64023167e+00]
#  [-6.91436401e-02  3.52184167e+00]
#  [ 7.48321369e-02  3.23718715e+00]
#  [-2.33573898e-01  3.98011455e+00]
#  [-3.24608508e-02  3.77040451e+00]
#  [-3.31063719e-03  3.36312669e+00]
#  [ 1.20159058e+00  2.05105851e+00]
#  [ 2.06137883e+00  2.21664146e+00]
#  [ 1.23616980e+00  2.06592285e+00]
#  [ 5.92728906e-01  1.56661840e+00]
#  [ 1.45925070e+00  2.12290695e+00]
#  [ 2.37934134e+00  2.27194390e+00]
#  [ 1.10577083e+00  2.24382480e+00]
#  [ 2.07177334e+00  2.23687349e+00]
#  [ 3.88852034e-01  1.58870404e+00]
#  [ 1.50347711e+00  2.48342509e+00]
#  [-6.19920403e-01  3.94176321e+00]
#  [-4.13756288e-01  3.76727600e+00]
#  [-4.92686248e-01  3.34569200e+00]
#  [-3.78366195e-01  1.91830862e+00]
#  [ 2.30553732e-01  3.05159726e+00]
#  [-8.20206310e-01  1.53478215e+00]
#  [-3.55847406e-01  3.66184659e+00]
#  [-4.83108531e-02  3.03418130e+00]
#  [-3.81298438e-01  3.91620614e+00]
#  [-7.51316401e-01  3.82681164e+00]
#  [-5.00402064e-01  3.76653129e+00]
#  [-3.42444044e-01  3.20456740e+00]
#  [-3.46266204e-01  3.18649219e+00]]
# [16 10 13]
# [16 10 13]

# %% [markdown]
# ### Using 5-fold cross validation compare the accuracies of each method

# %%
### Using 5-fold cross validation compare the accuracies of each method

from sklearn.model_selection import cross_val_score

# calculate the accuracy using 5-fold cross validation
scores = cross_val_score(svc, X, y, cv=5)
print(scores)
# Out:
# [0.99       0.99666667 1.         1.         1.        ]
